# %%
import pandas as pd
import seaborn as sns
import numpy as np
import plotly.plotly as py
import plotly.graph_objs as go
from sklearn import preprocessing
from sklearn.model_selection import cross_validate

from sklearn.linear_model import LinearRegression
url = 'https://raw.githubusercontent.com/shanksghub/FootballStats/master/FootballStats.csv'
df1 = pd.read_csv(url)

df1.plot()
df1.isnull().values.any()

Y = output(X)
df.read_csv("your_csv.csv")

df = pd.DataFrame.from_dict(data_dict)
df.head()

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.20, random_state=42)

reg = LinearRegression()
reg.fit(X_train.reshape(-1,1), Y_train.reshape(-1,1))
 Y_pred = reg.predict(X_test.reshape(-1,1))

# New Data Frame

data_dict2 = {'X_test': X_test.reshape(-1), 'Y_Predictions': Y_pred.reshape(-1), 'Y_test': Y_test.reshape(-1)}
regFrame = pd.DataFrame.from_dict(data_dict2)
regFrame.head()

# Visualize
plt.figure(figsize=(12,8))
plt.scatter(regFrame['X_test'], regFrame['Y_test'], color='green')
plt.plot(regFrame['X_test'], regFrame['Y_Predictions'], 'r-')
plt.title("Regression Plot", size=30)
plt.xlabel("X Labels", size=15)
plt.ylabel("Y Labels", size=15)

# r2 score Assessment

r_squared = r2_score(regFrame['Y_Predictions'], regFrame['Y_test'])
from IPython.display import display, Markdown
display(Markdown(f"$r^2$ = {r_squared}"))

# Mean Squared Error Assessment
mse = mean_squared_error(regFrame['Y_Predictions'], regFrame['Y_test'])
display(Markdown("$\\frac{1}{n}\\sum_{i=1}^{n}(y - \hat{y})^2$ =" + "{}".format(mse)))
# Out:
# True

# %%
 s = Series(data, index=index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-52e9913b078d> in <module>()
# ----> 1 df1.isnull().values.any()
#
# NameError: name 'df1' is not defined

# %%
df1.head()
# Out:
#                         name  position  appearances  goals  tackles  passes  \
# 0              Sergio Agüero   Forward           23     17       16   538.0
# 1            Aymeric Laporte  Defender           27      2       30  2313.0
# 2              Mohamed Salah   Forward           26     17       13   739.0
# 3  Pierre-Emerick Aubameyang   Forward           25     15       19   518.0
# 4                 Harry Kane   Forward           22     14        7   446.0
#
#    assists  shots  hit woordwork  crosses    ...     clearances  \
# 0        6     84              5        7    ...              3
# 1        1      0              0        6    ...             12
# 2        7     87              1       49    ...              4
# 3        4     63              3       26    ...             15
# 4        4     77              1        9    ...             11
#
#    headed clearances  clean sheets  saves  punches  goals conceded  \
# ...

# %%
df1.groupby('goals')['passes'].agg(np.median).plot(kind = 'bar')

# %%
df1.groupby('red cards')['yellow cards'].agg(np.median).plot(kind = 'bar')

# %%
df1.groupby('goals')['passes'].agg(np.median).plot(kind = 'bar')

# %%
df1.groupby('tackles')['shots'].agg(np.median).plot(kind = 'bar')

# %%
sns.lmplot(x="goals", y="passes", data=url, logistic=True, y_jitter=.03);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-82716c5ed080> in <module>()
#       1
# ----> 2 sns.lmplot(x="goals", y="passes", data=url, logistic=True, y_jitter=.03);
#
# /usr/local/lib/python3.6/dist-packages/seaborn/linearmodels.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     539     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     540     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 541     data = data[cols]
#     542
#     543     # Initialize the grid
#
# TypeError: string indices must be integers

# %%
sns.factorplot("crosses", "assists", data=df1, palette="PuBu_d", estimator=np.median);

# %%
df1.describe()
# Out:
#        appearances      goals      tackles       passes     assists  \
# count    46.000000  46.000000    46.000000    45.000000   46.000000
# mean     24.521739   5.000000    68.086957   862.822222   29.043478
# std       2.438024   5.420127   308.964495   409.217007  124.664342
# min      17.000000   0.000000     0.000000     1.000000    0.000000
# 25%      23.000000   0.000000     7.500000   633.000000    0.000000
# 50%      25.500000   3.000000    23.500000   748.000000    1.000000
# 75%      26.000000   9.750000    34.500000  1153.000000    4.000000
# max      27.000000  17.000000  2115.000000  2313.000000  691.000000
#
#            shots  hit woordwork     crosses      blocks  clearances  \
# count  46.000000      46.000000   46.000000   46.000000   46.000000
# mean   23.695652       2.826087   20.630435   22.173913   41.652174
# std    31.973510       9.153759   39.234542   37.806116   56.184307
# min     0.000000       0.000000    0.000000    0.000000    0.000000
# ...

# %%
melt = pd.melt(df1, id_vars = 'shots')

# %%
melt.iloc[0:47,0:3]
# Out:
#     shots  variable                      value
# 0      84      name              Sergio Agüero
# 1       0      name            Aymeric Laporte
# 2      87      name              Mohamed Salah
# 3      63      name  Pierre-Emerick Aubameyang
# 4      77      name                 Harry Kane
# 5      67      name                Eden Hazard
# 6       8      name                 Sadio Mané
# 7       3      name            Raheem Sterling
# 8      49      name        Alexandre Lacazette
# 9      93      name        Aleksandar Mitrovic
# 10     30      name            Anthony Martial
# 11     57      name            Roberto Firmino
# 12     81      name               Raúl Jiménez
# 13     47      name                Joshua King
# 14     55      name                Richarlison
# 15     79      name                 Paul Pogba
# 16     21      name              Son Heung-Min
# 17     63      name           Gylfi Sigurdsson
# 18      0      name                    Alisson
# ...

# %%
df1.shape
# Out:
# (46, 21)

# %%
gd1 = df1.groupby(['goals','shots' , 'passes']).mean()
gd1
# Out:
#                     appearances  tackles  assists  hit woordwork  crosses  \
# goals shots passes
# 0     0     532.0          26.0      0.0      0.0            0.0      0.0
#             666.0          26.0      0.0      0.0            0.0      0.0
#             702.0          27.0      0.0      1.0            0.0      0.0
#             721.0          22.0      0.0      0.0            0.0      0.0
#             731.0          26.0      0.0      0.0            0.0      0.0
#             740.0          26.0      0.0      0.0            0.0      0.0
#             741.0          26.0      0.0      0.0            0.0      0.0
#             748.0          26.0      0.0      0.0            0.0      0.0
#             770.0          22.0     25.0      1.0            1.0    150.0
#             791.0          27.0      0.0      0.0            0.0      0.0
#             826.0          27.0      0.0      0.0            0.0      0.0
# ...

# %%
 sns.regplot(x="passes", y="assists", data=df1)

# %%
 sns.regplot(x="goals", y="shots", data=df1);

# %%
df1.boxplot();

# %%
melt = pd.melt(df1, id_vars = 'goals')

# %%
melt.iloc[0:47,0:3]
# Out:
#     goals  variable                      value
# 0      17      name              Sergio Agüero
# 1       2      name            Aymeric Laporte
# 2      17      name              Mohamed Salah
# 3      15      name  Pierre-Emerick Aubameyang
# 4      14      name                 Harry Kane
# 5      12      name                Eden Hazard
# 6      12      name                 Sadio Mané
# 7      12      name            Raheem Sterling
# 8      10      name        Alexandre Lacazette
# 9      10      name        Aleksandar Mitrovic
# 10      9      name            Anthony Martial
# 11      9      name            Roberto Firmino
# 12      9      name               Raúl Jiménez
# 13      8      name                Joshua King
# 14     10      name                Richarlison
# 15     11      name                 Paul Pogba
# 16     11      name              Son Heung-Min
# 17      9      name           Gylfi Sigurdsson
# 18      0      name                    Alisson
# ...

# %%
df1.groupby('tackles')['shots'].agg(np.mean).plot(kind = 'bar')
