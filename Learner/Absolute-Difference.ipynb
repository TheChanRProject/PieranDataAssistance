# %% [markdown]
# # Absolute Difference

# %% [markdown]
# The absolute value of a number is the distance of that number from 0.
#
# $$ \mid \space n \mid = n $$
#
# $$ \mid \space -n \mid = n $$

# %%
from IPython.core.display import Image 
Image('numberline.png', height=500, width=800)

# %% [markdown]
# ## In Python Code:

# %%
print(abs(20))
print(abs(-20))
# Out:
# 20
# 20
